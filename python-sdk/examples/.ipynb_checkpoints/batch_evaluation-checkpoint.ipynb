# %%
from dotenv import load_dotenv

load_dotenv()
import sys

sys.path.append("..")

from langwatch.batch_evaluation import BatchEvaluation, DatasetEntry

def callback(entry: DatasetEntry):
    # generate messages for entry.input using your LLM
    # input_data = entry.get("input")
    # Assuming entry contains an "input" field

    # Process the input data using your LLM and generate a response
    # response = f"Generated response for input: {input_data}"
    # print(response)

    return {"output": "Hello! How can I help you today?"}


# Instantiate the BatchEvaluation object
evaluation = BatchEvaluation(
    dataset="python-test",  # Provide the actual dataset name here
    evaluations=["huggingface/bert_f1","huggingface/bert_precision","huggingface/bert_recall","google-cloud-dlp-pii-detection","openai-moderation","azure-content-safety","ragas-answer-relevancy","ragas-context-relevancy","ragas-context-utilization","ragas-faithfulness","lingua-language-detection","custom-llm-boolean-evaluator","custom-llm-score-evaluator","semantic-similarity-evaluator","azure-jailbreak-detection","off-topic-evaluator"],
    callback=callback,
    generations="one-shot",
)

# Run the evaluation
results = evaluation.run()
# Out:
# Starting batch evaluation...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:21<00:00, 10.97s/it]

# %%
results.df
# Out:
#        input                                     expectedOutput  \
# 0         hi  Hey there! It's great to chat with you. I'm he...
# 1  aaaaaaaaa  Hey there! It looks like you're in need of som...
# 2         hi                  Hey! 👋🏻 How can I help you today?
# 3      hello                 👋 Hello! How can I help you today?
# 4         hi  Hey there! It's great to chat with you. I've b...
# 5  aaaaaaaaa  It looks like you might have accidentally ente...
# 6   hi there
#
#                              output ragas/answer_relevancy  \
# 0  Hello! How can I help you today?                    0.0
# 1  Hello! How can I help you today?                    0.0
# 2  Hello! How can I help you today?                    0.0
# 3  Hello! How can I help you today?                    0.0
# 4  Hello! How can I help you today?                  error
# 5  Hello! How can I help you today?                    0.0
# 6  Hello! How can I help you today?                  error
#
#   lingua/language_detection custom/llm_score
# 0                     error            error
# 1                   skipped              0.6
# 2                   skipped              0.7
# 3                   skipped              0.8
# 4                   skipped              0.8
# 5                   skipped              0.1
# 6                   skipped              1.0
